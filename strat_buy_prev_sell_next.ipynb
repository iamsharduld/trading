# %%
import numpy
import pandas as pd
import yfinance as yf


# Movement Types

# 1. Stocks rise from current day's close to next day's open '/' movement
# 2. Stocks rise on a given day from Open to Close '//'
# 3. Stocks fall from current day's close to next day's open '\'
# 4. Stocks fall on a given day from Open to Close '\\'

'''
For a given stock, 

1. we want to have signal for if we want to buy the stock on a close of particular day
2. we want to hold it the next day or sell at open


Also, it's a good idea to develop algorithm for a given stocks instead of generalising


Note:

General movement of stock can vary from earnings to earnings


1. TSLA

Start of day sell, buying close prev day works really well!




'''
# Out:
# "\nFor a given stock, \n\n1. we want to have signal for if we want to buy the stock on a close of particular day\n2. we want to hold it the next day or sell at open\n\n\nAlso, it's a good idea to develop algorithm for a given stocks instead of generalising\n\n1. TSLA\n\nStart of day sell, buying close prev day works really well!\n\n\n\n\n"

# %%
df = yf.download("TGT", start="2021-06-1", end="2021-09-1", interval="1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df['ClosePrev'] = df['Close'].shift(1)
df['OpenNext'] = df['Open'].shift(-1)

# %%
# num_stocks = 10
df['Prof'] = df['Open']-df['ClosePrev']
df['openProfPercent'] = 10000*(df['Prof']/df['ClosePrev'])
df['isHighMoreThanClose'] = df['High'] > df['ClosePrev']
df['best'] = 10000*((df['High'] - df['ClosePrev']))/df['ClosePrev']
df['worked'] = df['isHighMoreThanClose'] | (df['Prof'] > 0)
df['cross'] = (df['High'] > df['ClosePrev']) & ( df['ClosePrev'] > df['Open'])
df['CloseOpenCross'] = (df['OpenNext'] > df['Close'])
df['OpenOpenCross'] = (df['OpenNext'] > df['Open'])

df['sellEODProf'] = 10000*((df['Close'] - df['ClosePrev']))/df['ClosePrev']
df['% Change'] = 100*((df['Close'] - df['ClosePrev']))/df['ClosePrev']

df['strat%'] = df['openProfPercent']
df.loc[(df['Prof'] < 0) & (~df['cross']), 'strat%'] = df['sellEODProf']
df.loc[(df['Prof'] < 0) & (df['cross']), 'strat%'] = 0
# df.loc[(df['Prof'] > 0) & (df['sellEODProf'] < 0), 'movement'] = "\\"
df.loc[(df['Low'] < df['ClosePrev']), 'isBelowPrevClose'] = True
df.loc[(df['Low'] > df['ClosePrev']), 'isBelowPrevClose'] = False

# df.loc[(df['OpenNext'] > df['ClosePrev']) & df['isBelowPrevClose'], 'movement'] = "/"
# df.loc[(df['Open'] > df['ClosePrev']) & (df['Close'] < df['OpenNext']), 'movement'] = "\\"
# df.loc[(df['Close'] < df['OpenNext']), 'movementCloseToOpen'] = "/"
# df.loc[(df['Close'] > df['OpenNext']), 'movementCloseToOpen'] = "\\"
# df.loc[(df['Open'] < df['Close']), 'movementOpenToClose(Day)'] = "//"
# df.loc[(df['Open'] > df['Close']), 'movementOpenToClose(Day)'] = "\\\\"
df.loc[(df['OpenNext'] - df['Open']) > (df['OpenNext'] - df['Close']), 'Action'] = 'BuyAtOpen'
df.loc[(df['OpenNext'] - df['Open']) < (df['OpenNext'] - df['Close']), 'Action'] = 'BuyAtClose'


df.loc[(df['Action'] == 'BuyAtOpen') & (df['OpenNext'] - df['Open'] < 0), 'Action'] = 'NA'
df.loc[(df['Action'] == 'BuyAtClose') & (df['OpenNext'] - df['Close'] < 0), 'Action'] = 'NA'

# 2021-07-26  2338000  261.029999  260.000000 -0.149994        -5.746232  ...
# 2021-07-27  3036100  260.859985  257.290009 -0.859985       -32.967316  ...
#
#                   best  worked  cross  CloseOpenCross  OpenOpenCross  \
# Date
# 2021-06-01         NaN   False  False           False          False
# 2021-06-02   82.280771    True   True           False           True
# 2021-06-03   81.004939    True   True            True           True
# 2021-06-04  106.030544    True  False            True           True
# 2021-06-07   57.059192    True  False            True           True
# 2021-06-08  236.909404    True  False           False           True
# 2021-06-09   72.309524    True   True           False          False
# 2021-06-10   75.881456    True   True            True           True
# 2021-06-11   56.979714    True  False            True           True
# 2021-06-14   24.040420    True  False           False          False
# 2021-06-15   -2.574884   False  False            True          False
# 2021-06-16   18.488742    True  False           False          False
# 2021-06-17   72.213016    True   True           False          False
# 2021-06-18    6.487064    True   True            True           True
# 2021-06-21  152.257603    True  False            True           True
# 2021-06-22  174.958132    True  False           False           True
# 2021-06-23   32.038889    True   True            True           True
# 2021-06-24  107.875673    True  False            True           True
# 2021-06-25   79.219863    True  False            True           True
# 2021-06-28   70.255765    True  False           False           True
# 2021-06-29   91.188438    True  False           False           True
# 2021-06-30   45.482358    True   True            True           True
# 2021-07-01   74.046217    True  False            True           True
# 2021-07-02  144.165379    True  False           False           True
# 2021-07-06   30.821417    True   True            True          False
# 2021-07-07  120.187288    True  False           False          False
# 2021-07-08   56.958337    True   True            True           True
# 2021-07-09   87.295766    True  False            True           True
# 2021-07-12  156.488831    True  False           False           True
# 2021-07-13   47.573617    True   True            True           True
# 2021-07-14   91.360598    True  False            True           True
# 2021-07-15   35.484520    True  False            True           True
# 2021-07-16   44.281438    True  False           False          False
# 2021-07-19   26.677820    True   True           False           True
# 2021-07-20  209.462005    True   True            True           True
# 2021-07-21   67.527224    True  False            True           True
# 2021-07-22   67.956291    True  False            True           True
# 2021-07-23  159.525911    True  False           False           True
# 2021-07-26   51.718427    True   True           False          False
# 2021-07-27  -22.999909   False  False           False          False
#
#             sellEODProf  % Change      strat%  isBelowPrevClose      Action
# Date
# 2021-06-01          NaN       NaN         NaN               NaN          NA
# 2021-06-02    48.840612  0.488406    0.000000              True   BuyAtOpen
# 2021-06-03    35.028802  0.350288    0.000000              True   BuyAtOpen
# 2021-06-04    94.249225  0.942492   44.506689              True   BuyAtOpen
# 2021-06-07   -19.451757 -0.194518    6.916386              True  BuyAtClose
# 2021-06-08   182.338201  1.823382  146.390268             False   BuyAtOpen
# 2021-06-09  -134.411041 -1.344110    0.000000              True          NA
# 2021-06-10   -12.072035 -0.120720    0.000000              True         NaN
# 2021-06-11    55.253335  0.552533    5.611224             False   BuyAtOpen
# 2021-06-14     5.581046  0.055810    9.444544              True          NA
# 2021-06-15   -21.452782 -0.214528  -21.452782              True  BuyAtClose
# 2021-06-16   -56.327677 -0.563277    5.589269              True          NA
# 2021-06-17    -1.729365 -0.017294    0.000000              True          NA
# 2021-06-18   -29.841815 -0.298418    0.000000              True   BuyAtOpen
# 2021-06-21   140.545938  1.405459   38.173118             False   BuyAtOpen
# 2021-06-22   147.153287  1.471533   30.799555             False   BuyAtOpen
# 2021-06-23     4.215288  0.042153    0.000000              True   BuyAtOpen
# 2021-06-24   106.611555  1.066116   89.756222             False   BuyAtOpen
# 2021-06-25    29.603349  0.296033    7.087982              True   BuyAtOpen
# 2021-06-28    29.515338  0.295153   14.549609              True   BuyAtOpen
# 2021-06-29    24.455426  0.244554    0.000000              True   BuyAtOpen
# 2021-06-30    -4.548299 -0.045483    0.000000              True  BuyAtClose
# 2021-07-01    71.564312  0.715643    9.100737              True   BuyAtOpen
# 2021-07-02   127.736501  1.277365   42.304956             False   BuyAtOpen
# 2021-07-06   -45.827110 -0.458271    0.000000              True  BuyAtClose
# 2021-07-07    85.557390  0.855574    6.518789             False          NA
# 2021-07-08    41.607706  0.416077    0.000000              True   BuyAtOpen
# 2021-07-09     0.000000  0.000000    4.022481              True  BuyAtClose
# 2021-07-12   147.236448  1.472364   37.010144             False   BuyAtOpen
# 2021-07-13   -19.426161 -0.194262    0.000000              True   BuyAtOpen
# 2021-07-14    74.677453  0.746775   33.763897              True   BuyAtOpen
# 2021-07-15   -27.599740 -0.275997    2.759613              True  BuyAtClose
# 2021-07-16   -70.375156 -0.703752   38.350581              True          NA
# 2021-07-19    -1.194457 -0.011945    0.000000              True   BuyAtOpen
# 2021-07-20   142.960006  1.429600    0.000000              True   BuyAtOpen
# 2021-07-21    52.608105  0.526081   21.200317              True   BuyAtOpen
# 2021-07-22    37.493537  0.374935   52.724318              True  BuyAtClose
# 2021-07-23   156.413714  1.564137   29.959495             False   BuyAtOpen
# 2021-07-26    -6.513176 -0.065132    0.000000              True          NA
# 2021-07-27   -95.836853 -0.958369  -95.836853              True          NA
#
# [40 rows x 21 columns]

# %%
df['% Change'].to_csv("tslaChange.csv")

# %%
x = df['% Change'].to_numpy()
tmp = [0]
summ = 0
ba = 0
for i in range(1, len(x)):
    if summ == 0:
        summ = x[i]
    else:
        if x[i]*x[i-1] < 0:
            summ = x[i]
        else:
            summ += x[i]
    ba += x[i]
    tmp.append(summ)
    print(ba)
dff = pd.DataFrame(tmp,columns=['CumuChange'])
dff.set_index(df.index, inplace=True)
dff.tail(50)

df = pd.concat([df, dff], axis=1)
df.tail(20)
# Out:
# 0.48840612024666774
# 0.8386941384027422
# 1.7811863851692875
# 1.586668811310191
# 3.4100508222228454
# 2.0659404096020944
# 1.9452200610854087
# 2.497753411280738
# 2.553563869531764
# 2.339036052014489
# 1.7757592853948947
# 1.758465638814085
# 1.4600474925622682
# 2.8655068732591618
# 4.337039738269891
# 4.379192616266803
# 5.445308163578373
# 5.741341654534118
# 6.036495030576836
# 6.281049291587138
# 6.235566303133344
# 6.951209427245039
# 8.228574439262424
# 7.770303340867864
# 8.625877237639372
# 9.041954299485145
# 9.041954299485145
# 10.514318783815973
# 10.32005717483526
# 11.066831706240423
# 10.790834310997425
# 10.087082746991108
# 10.075138179988953
# 11.504738238321375
# 12.030819288842038
# 12.405754660224474
# 13.969891799216773
# 13.904760040978472
# 12.946391513651164
# 12.58256894935234
# 14.229678736162017
# 13.996545715981997
# 12.537056063902277
# 14.465225151506854
# 13.828301677065616
# 14.162234476076796
# 13.661087731937041
# 14.553089483978576
# 15.185688713787997
# 14.784280932065814
# 14.354637633006787
# 14.22480857712191
#                   Open        High         Low       Close   Adj Close  \
# Date
# 
# 2021-07-23    True  False           False           True   156.413714
# 2021-07-26    True   True           False          False    -6.513176
# 2021-07-27   False  False           False          False   -95.836853
# 2021-07-28    True   True            True           True   -36.382256
# 2021-07-29    True  False           False           True   164.710979
# 2021-07-30    True   True            True           True   -23.313302
# 2021-08-02    True  False            True          False  -145.948965
# 2021-08-03    True  False           False           True   192.816909
# 2021-08-04    True   True            True           True   -63.692347
# 2021-08-05    True  False            True           True    33.393280
# 2021-08-06    True  False            True          False   -50.114674
# 2021-08-09    True  False            True           True    89.200175
# 2021-08-10    True  False            True           True    63.259923
# 2021-08-11    True  False            True          False   -40.140778
# 2021-08-12    True  False            True          False   -42.964330
# 2021-08-13    True  False           False          False   -12.982906
#
#             % Change     strat%  isBelowPrevClose      Action CumuChange
# Date
# 2021-07-19 -0.011945   0.000000              True   BuyAtOpen  -0.991694
# 2021-07-20  1.429600   0.000000              True   BuyAtOpen   1.429600
# 2021-07-21  0.526081  21.200317              True   BuyAtOpen   1.955681
# 2021-07-22  0.374935  52.724318              True  BuyAtClose   2.330616
# 2021-07-23  1.564137  29.959495             False   BuyAtOpen   3.894754
# 2021-07-26 -0.065132   0.000000              True          NA  -0.065132
# 2021-07-27 -0.958369 -95.836853              True          NA  -1.023500
# 2021-07-28 -0.363823   0.000000              True   BuyAtOpen  -1.387323
# 2021-07-29  1.647110  29.911777              True   BuyAtOpen   1.647110
# 2021-07-30 -0.233133   0.000000              True   BuyAtOpen  -0.233133
# 2021-08-02 -1.459490  39.455998              True  BuyAtClose  -1.692623
# 2021-08-03  1.928169  33.820368             False   BuyAtOpen   1.928169
# 2021-08-04 -0.636923   0.000000              True  BuyAtClose  -0.636923
# 2021-08-05  0.333933  47.594912              True  BuyAtClose   0.333933
# 2021-08-06 -0.501147  20.275394              True  BuyAtClose  -0.501147
# 2021-08-09  0.892002   0.384858              True   BuyAtOpen   0.892002
# 2021-08-10  0.632599  21.340557              True   BuyAtOpen   1.524601
# 2021-08-11 -0.401408  18.176258              True  BuyAtClose  -0.401408
# 2021-08-12 -0.429643  35.740177              True  BuyAtClose  -0.831051
# 2021-08-13 -0.129829  30.930103              True         NaN  -0.960880
#
# [20 rows x 22 columns]

# %%
df[['worked','openProfPercent', 'sellEODProf', 'strat%', 'cross', 'CumuChange', 'CloseOpenCross', 'OpenOpenCross']].head(60)
# Out:
#             worked  openProfPercent  sellEODProf      strat%  cross  \
# Date
# 2021-06-01   False              NaN          NaN         NaN  False
# 2021-06-02    True       -37.840480    48.840612    0.000000   True
# 2021-06-03    True        -1.751841    35.028802    0.000000   True
# 2021-06-04    True        44.506689    94.249225   44.506689  False
# 2021-06-07    True         6.916386   -19.451757    6.916386  False
# 2021-06-08    True       146.390268   182.338201  146.390268  False
# 2021-06-09    True       -21.267545  -134.411041    0.000000   True
# 2021-06-10    True       -12.072035   -12.072035    0.000000   True
# 2021-06-11    True         5.611224    55.253335    5.611224  False
# 2021-06-14    True         9.444544     5.581046    9.444544  False
# 2021-06-15   False        -2.574884   -21.452782  -21.452782  False
# 2021-06-16    True         5.589269   -56.327677    5.589269  False
# 2021-06-17    True       -30.701006    -1.729365    0.000000   True
# 2021-07-01    0.715643            True           True
# 2021-07-02    1.993008           False           True
# 2021-07-06   -0.458271            True          False
# 2021-07-07    0.855574           False          False
# 2021-07-08    1.271651            True           True
# 2021-07-09    1.271651            True           True
# 2021-07-12    2.744015           False           True
# 2021-07-13   -0.194262            True           True
# 2021-07-14    0.746775            True           True
# 2021-07-15   -0.275997            True           True
# 2021-07-16   -0.979749           False          False
# 2021-07-19   -0.991694           False           True
# 2021-07-20    1.429600            True           True
# 2021-07-21    1.955681            True           True
# 2021-07-22    2.330616            True           True
# 2021-07-23    3.894754           False           True
# 2021-07-26   -0.065132           False          False
# 2021-07-27   -1.023500           False          False
# 2021-07-28   -1.387323            True           True
# 2021-07-29    1.647110           False           True
# 2021-07-30   -0.233133            True           True
# 2021-08-02   -1.692623            True          False
# 2021-08-03    1.928169           False           True
# 2021-08-04   -0.636923            True           True
# 2021-08-05    0.333933            True           True
# 2021-08-06   -0.501147            True          False
# 2021-08-09    0.892002            True           True
# 2021-08-10    1.524601            True           True
# 2021-08-11   -0.401408            True          False
# 2021-08-12   -0.831051            True          False
# 2021-08-13   -0.960880           False          False

# %%
# summ = sum(df['actual'])
sellEODProfReturn = df['sellEODProf'].sum() # Similar to holding the stock
sellEODProfReturn
# Out:
# 1422.480857712191

# %%
sellSODProfReturn = df['strat%'].sum() # More consistent positive returns (Stocks which tend to go up pre market are successful eg. COIN coinbase)
sellSODProfReturn
# Out:
# 836.8809636576469

# %%
x = df.tail(1)['Close']
y = df.head(1)['Close']
x,y
# Out:
# (Date
#  2021-08-13    261.540009
#  Name: Close, dtype: float64,
#  Date
#  2021-06-01    227.270004
#  Name: Close, dtype: float64)

# %%
100*((x.iloc[0]-y.iloc[0])/x.iloc[0])
# Out:
# 13.103159422194006

# %%
sellEODProfReturn/100
# Out:
# 14.22480857712191

# %%
sellSODProfReturn/100
# Out:
# 8.368809636576469

# %%
def cumuChangeDirection(ticker='AMZN'):
    df = yf.download(ticker, start="2021-05-7", end="2021-08-14", interval="1d")
    df['ClosePrev'] = df['Close'].shift(1)
    df['% Change'] = 100*((df['Close'] - df['ClosePrev']))/df['ClosePrev']
    
    x = df['% Change'].to_numpy()
    tmp = [0]
    summ = 0
    ba = 0
    for i in range(1, len(x)):
        if summ == 0:
            summ = x[i]
        else:
            if x[i]*x[i-1] < 0:
                summ = x[i]
            else:
                summ += x[i]
        ba += x[i]
        tmp.append(summ)
    dff = pd.DataFrame(tmp,columns=['CumuChange'])
    dff.set_index(df.index, inplace=True)
    dff.tail(50)

    df = pd.concat([df, dff], axis=1)

    if df.tail(1)['CumuChange'].iloc[0] < 0:
        return (ticker,'Negative', df.tail(1)['CumuChange'].iloc[0])
    else:
        return (ticker, 'Positive', df.tail(1)['CumuChange'].iloc[0])



stock_tickers = [
    'PYPL',
    'AMZN',
    'ROKU',
    'NVDA',
    'GOOGL',
    'NDAQ',
    'TSLA',
    'AXP',
    'BX',
    'NOK',
    'MS',
    'NFLX',
    'SNAP',
    'CLF', 
    'M',
    'CMG',
    'ADBE',
    'EBAY',
    'AAPL'
]

# for ticker in stock_tickers:
#     print(cumuChangeDirection(ticker))
